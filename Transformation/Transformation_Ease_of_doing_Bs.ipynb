# %%
#Importer les librairies necessaires pour notre traitement
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# ### **Explorer nos données**: 👁

# %%
#Charger les données
df = pd.read_csv("/content/Ease of doing business.csv", delimiter=';')
display(df)
# Out:
#    id_pays             Country  2019  2020
# 0        1       United States  83,6    84
# 1        2               Japan    78    78
# 2        3             Germany  79,3  79,7
# 3        4               China    74  77,9
# 4        5  Russian Federation  77,4  78,2
# 5        6             Morocco  71,7  73,4
# 6        7        Saudi Arabia  63,8  71,6
# 7        8             Ukraine  69,1  70,2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id_pays  8 non-null      int64
#  1   Country  8 non-null      object
#  2   2019     8 non-null      object
#  3   2020     8 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 384.0+ bytes

# %% [markdown]
# ### *Effectuer une opération de Pivot *

# %%
# Utiliser la fonction `melt` pour convertir les colonnes 2005 à 2022 en une seule colonne 'date'
df_melted = pd.melt(df, id_vars=['id_pays', 'Country'], var_name='date', value_name='valeur')

# Utiliser la fonction `pivot` pour obtenir les types d'investissement comme colonnes
df = df_melted.pivot_table(index=['id_pays', 'Country', 'date'], values='valeur', aggfunc='sum').reset_index()

# %%
display(df)
# Out:
#     id_pays             Country  date valeur
# 0         1       United States  2019   83,6
# 1         1       United States  2020     84
# 2         2               Japan  2019     78
# 3         2               Japan  2020     78
# 4         3             Germany  2019   79,3
# 5         3             Germany  2020   79,7
# 6         4               China  2019     74
# 7         4               China  2020   77,9
# 8         5  Russian Federation  2019   77,4
# 9         5  Russian Federation  2020   78,2
# 10        6             Morocco  2019   71,7
# 11        6             Morocco  2020   73,4
# 12        7        Saudi Arabia  2019   63,8
# 13        7        Saudi Arabia  2020   71,6
# 14        8             Ukraine  2019   69,1
# 15        8             Ukraine  2020   70,2

# %%
df['valeur'] =  df['valeur'].str.replace(',', '.').astype(float)
df['date'] = pd.to_datetime(df['date'], format='%Y')
df['date'] = df['date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id_pays  16 non-null     int64
#  1   Country  16 non-null     object
#  2   date     16 non-null     int64
#  3   valeur   16 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 640.0+ bytes

# %%
display(df)
# Out:
#     id_pays             Country  date  valeur
# 0         1       United States  2019    83.6
# 1         1       United States  2020    84.0
# 2         2               Japan  2019    78.0
# 3         2               Japan  2020    78.0
# 4         3             Germany  2019    79.3
# 5         3             Germany  2020    79.7
# 6         4               China  2019    74.0
# 7         4               China  2020    77.9
# 8         5  Russian Federation  2019    77.4
# 9         5  Russian Federation  2020    78.2
# 10        6             Morocco  2019    71.7
# 11        6             Morocco  2020    73.4
# 12        7        Saudi Arabia  2019    63.8
# 13        7        Saudi Arabia  2020    71.6
# 14        8             Ukraine  2019    69.1
# 15        8             Ukraine  2020    70.2

# %%
#Enregistrer le dataframe transformé en fichier csv
df.to_csv('trasformed_Ease_of_doing_Bs.csv', index=False)
